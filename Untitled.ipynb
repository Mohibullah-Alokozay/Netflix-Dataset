# %% [markdown]
# # Netflix Movies and TV Shows Dataset

# %% [markdown]
# # # Information About This Dataset
#
# Netflix is a subscription-based streaming service that allows our members to watch TV shows and movies without commercials on an internet-connected device.
#
# You can also download TV shows and movies to your iOS, Android, or Windows 10 device and watch without an internet connection.
#
# If you're already a member and would like to learn more about using Netflix, visit Getting started with Netflix.
#
# # #TV Shows & Movies
# Rows of images at an angle showing different tv shows and movies streaming on Netlfix
# Netflix content varies by region and may change over time. You can watch from a wide variety of award-winning Netflix Originals, TV shows, movies, documentaries, and more.
#
# The more you watch, the better Netflix gets at recommending TV shows and movies we think you’ll enjoy.
# # # Column Description
# *Title: title of Movies,
# *rating,
# *ratingLevel,
# *ratingDescription,
# *release year,
# *user rating score,
# *user rating size

# %%
import numpy as np
import pandas as mo
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
data = mo.read_csv('WorkingFile.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data.tail()
# Out:
#                        title rating  \
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release year  user rating score  user rating size
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# ...

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.size
# Out:
# 7000

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ...

# %%
data[data.duplicated()]
# Out:
#                           title rating  \
# 50          Lucky Number Slevin      R
# 52               Grey's Anatomy  TV-14
# 53                 Prison Break  TV-14
# 56        How I Met Your Mother  TV-PG
# 57                 Supernatural  TV-14
# ..                          ...    ...
# 991          Dawn of the Croods  TV-Y7
# 992  Alpha and Omega: Dino Digs   TV-G
# 995                     The BFG     PG
# 996     The Secret Life of Pets     PG
# 999             Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 50   strong violence, sexual content and adult lang...                100
# 52   Parents strongly cautioned. May be unsuitable ...                 90
# 53   Parents strongly cautioned. May be unsuitable ...                 90
# 56   Parental guidance suggested. May not be suitab...                 70
# 57   Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
data.drop_duplicates()
# Out:
#                          title rating  \
# 0                 White Chicks  PG-13
# 1          Lucky Number Slevin      R
# 2               Grey's Anatomy  TV-14
# 3                 Prison Break  TV-14
# 4        How I Met Your Mother  TV-PG
# ..                         ...    ...
# 989            Russell Madness     PG
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ...

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [title, rating, ratingLevel, ratingDescription, release year, user rating score, user rating size]
# Index: []

# %% [markdown]
# ## HeatMap Of This Dataset

# %%
data.isnull()
# Out:
#      title  rating  ratingLevel  ratingDescription  release year  \
# 0    False   False        False              False         False
# 1    False   False        False              False         False
# 2    False   False        False              False         False
# 3    False   False        False              False         False
# 4    False   False        False              False         False
# ..     ...     ...          ...                ...           ...
# 989  False   False        False              False         False
# 993  False   False        False              False         False
# 994  False   False        False              False         False
# 997  False   False        False              False         False
# 998  False   False        False              False         False
#
#      user rating score  user rating size
# 0                False             False
# 1                 True             False
# 2                False             False
# ...

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           33
# ratingDescription      0
# release year           0
# user rating score    244
# user rating size       0
# dtype: int64

# %% [markdown]
# # Seaborn Library (heat_map) For This Dataset

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data['title']
# Out:
# 0                   White Chicks
# 1            Lucky Number Slevin
# 2                 Grey's Anatomy
# 3                   Prison Break
# 4          How I Met Your Mother
#                  ...
# 989              Russell Madness
# 993    Wiener Dog Internationals
# 994                     Pup Star
# 997             Precious Puppies
# 998                  Beary Tales
# Name: title, Length: 500, dtype: object

# %%
data[data['title'].isin(['Prison Break'])]
# Out:
#           title rating                                        ratingLevel  \
# 3  Prison Break  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    ratingDescription  release year  user rating score  user rating size
# 3                 90          2008               98.0                80

# %% [markdown]
# # In Whiche Years Highest number Of TV Show & movie Were Released

# %%
data.dtypes
# Out:
# title                 object
# rating                object
# ratingLevel           object
# ratingDescription      int64
# release year           int64
# user rating score    float64
# user rating size       int64
# dtype: object

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
data.dtypes
# Out:
# title                 object
# rating                object
# ratingLevel           object
# ratingDescription      int64
# release year           int64
# user rating score    float64
# user rating size       int64
# dtype: object

# %% [markdown]
# # Droping Null values

# %%
data.dropna().head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80
# 5          2016               95.0                80

# %%
data.dropna(axis = 1).head(4)
# Out:
#                  title rating  ratingDescription  release year  \
# 0         White Chicks  PG-13                 80          2004
# 1  Lucky Number Slevin      R                100          2006
# 2       Grey's Anatomy  TV-14                 90          2016
# 3         Prison Break  TV-14                 90          2008
#
#    user rating size
# 0                80
# 1                82
# 2                80
# 3                80

# %%
data.dropna(how='all')
# Out:
#                          title rating  \
# 0                 White Chicks  PG-13
# 1          Lucky Number Slevin      R
# 2               Grey's Anatomy  TV-14
# 3                 Prison Break  TV-14
# 4        How I Met Your Mother  TV-PG
# ..                         ...    ...
# 989            Russell Madness     PG
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ...

# %%
data.dropna(how='any')
# Out:
#                         title rating  \
# 0                White Chicks  PG-13
# 2              Grey's Anatomy  TV-14
# 3                Prison Break  TV-14
# 4       How I Met Your Mother  TV-PG
# 5                Supernatural  TV-14
# ..                        ...    ...
# 966               Blank Check     PG
# 967              Heavyweights     PG
# 972      D2: The Mighty Ducks     PG
# 973  Honey, I Shrunk the Kids     PG
# 979       H2O: Just Add Water  TV-PG
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# 5    Parents strongly cautioned. May be unsuitable ...                 90
# ...

# %%
data.dropna(subset = ['title'])
# Out:
#                          title rating  \
# 0                 White Chicks  PG-13
# 1          Lucky Number Slevin      R
# 2               Grey's Anatomy  TV-14
# 3                 Prison Break  TV-14
# 4        How I Met Your Mother  TV-PG
# ..                         ...    ...
# 989            Russell Madness     PG
# 993  Wiener Dog Internationals      G
# 994                   Pup Star      G
# 997           Precious Puppies   TV-G
# 998                Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ...

# %% [markdown]
# # How Many Movies & TV Shows are in the Dataset Show Whit Bar Graph

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data.groupby('title')

# %%
data.groupby('title').title.count()
# Out:
# title
# 10 Things I Hate About You    1
# 100 Metros                    1
# 13 Reasons Why                1
# 3%                            1
# 30 Rock                       1
#                              ..
# Yellowbird                    1
# Young Justice                 1
# Zoobabu                       1
# Zootopia                      1
# ÌÒ Pai, ÌÒ - Look at This     1
# Name: title, Length: 496, dtype: int64

# %%
sns.countplot(data['title'])
# Out:
# <AxesSubplot:xlabel='title', ylabel='count'>

# %%
sns.countplot(data['ratingDescription'])
# Out:
# <AxesSubplot:xlabel='ratingDescription', ylabel='count'>

# %% [markdown]
# # Show All the Movies that were Releases in 2014

# %%
sns.countplot(data['user rating score'])
# Out:
# <AxesSubplot:xlabel='user rating score', ylabel='count'>

# %%
sns.countplot(data['user rating size'])
# Out:
# <AxesSubplot:xlabel='user rating size', ylabel='count'>

# %%
sns.countplot(data['release year'])
# Out:
# <AxesSubplot:xlabel='release year', ylabel='count'>

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %% [markdown]
# # Show top 10 rating who give The Heighest number of TV Show & Movies to Netflix

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data['rating'].value_counts()
# Out:
# TV-14       106
# TV-MA        82
# PG           76
# G            53
# TV-Y         36
# TV-PG        33
# TV-G         29
# TV-Y7-FV     25
# TV-Y7        23
# R            14
# PG-13        12
# NR           10
# UR            1
# Name: rating, dtype: int64

# %%
data['rating'].value_counts().head(10)
# Out:
# TV-14       106
# TV-MA        82
# PG           76
# G            53
# TV-Y         36
# TV-PG        33
# TV-G         29
# TV-Y7-FV     25
# TV-Y7        23
# R            14
# Name: rating, dtype: int64

# %% [markdown]
# # Creating new data Frame

# %%
data_new = data.dropna()

# %%
data_new.head(2)
# Out:
#             title rating                                        ratingLevel  \
# 0    White Chicks  PG-13  crude and sexual humor, language and some drug...
# 2  Grey's Anatomy  TV-14  Parents strongly cautioned. May be unsuitable ...
#
#    ratingDescription  release year  user rating score  user rating size
# 0                 80          2004               82.0                80
# 2                 90          2016               98.0                80

# %% [markdown]
# # What are diffrent rating Definde by Netflix

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'R', 'TV-14', 'TV-PG', 'TV-MA', 'TV-Y', 'NR', 'TV-Y7-FV',
#        'UR', 'PG', 'TV-G', 'G', 'TV-Y7'], dtype=object)

# %% [markdown]
# # What is the Maximum User Rating Score of A movie Show on Netflix

# %%
data['user rating score'].max()
# Out:
# 99.0

# %%
data['user rating score'].min()
# Out:
# 55.0

# %%
print("Mean",data['user rating size'].mean())
print("Median",data['user rating size'].median())
print("Minimum value",data['user rating size'].min())
print("Maximum value",data['user rating size'].max())
plt.boxplot(data['user rating size'])
plt.show()
# Out:
# Mean 80.972
# Median 80.0
# Minimum value 80
# Maximum value 82

# %% [markdown]
# # Mean ,Madain, IQR

# %%
sns.distplot(data['user rating size'])
# Out:
# <AxesSubplot:xlabel='user rating size'>

# %%
sns.distplot(data['ratingDescription'])
# Out:
# <AxesSubplot:xlabel='ratingDescription'>

# %%
sns.distplot(data['release year'])
# Out:
# <AxesSubplot:xlabel='release year'>

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %% [markdown]
# # How Can We Sort The Dataset By User Rating Size

# %%
data.head(2)
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82

# %%
data.sort_values(by='user rating size')
# Out:
#                                              title rating  \
# 0                                     White Chicks  PG-13
# 387                                      The Crown  TV-MA
# 766                                          Balto      G
# 382                         Marvel's Jessica Jones  TV-MA
# 381                              London Has Fallen      R
# ..                                             ...    ...
# 503                   Teenage Mutant Ninja Turtles     PG
# 485                                 American Crime  TV-14
# 479                                        Rectify  TV-14
# 511  LeapFrog: The Amazing Alphabet Amusement Park   TV-Y
# 998                                    Beary Tales   TV-G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 387  For mature audiences.  May not be suitable for...                110
# ...

# %%
data.sort_values(by='user rating size').ascending=False

# %%
data.head()
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80
# 3          2008               98.0                80
# 4          2014               94.0                80

# %%
labels=['title','rating','user rating score','user rating size']
colors=['blue','yellow','green','orange']
sizes=[100,1000,900,1100]
plt.pie(sizes,labels=labels,colors=colors,startangle=90,shadow=True,explode=(0.1,0.1,0.1,0.1),autopct='%1.2f%%')
plt.title('Presion Break')
plt.axis('equal')
plt.show()
